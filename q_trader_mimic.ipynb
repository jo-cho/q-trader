# %% [markdown]
# <a href="https://colab.research.google.com/github/jo-cho/q-trader/blob/master/q_trader_mimic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jo-cho/q-trader.git
# Out:
# Cloning into 'q-trader'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 75 (delta 3), reused 0 (delta 0), pack-reused 66
# Unpacking objects: 100% (75/75), done.

# %%
cd q-trader
# Out:
# /content/q-trader

# %% [markdown]
# # Let's run it

# %% [markdown]
# ## Training

# %%
# !mkdir models

# %%
! python train.py ^GSPC 10 2
#snp, window=10, episode=0,1,2 (시간상..)
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W1206 08:16:27.335284 139759028971392 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1206 08:16:27.340581 139759028971392 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1206 08:16:27.344562 139759028971392 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %% [markdown]
# ## Evaluate

# %%
! python evaluate.py ^GSPC_2011 model_ep0
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W1206 08:58:01.521404 140707991725952 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1206 08:58:01.523333 140707991725952 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1206 08:58:01.581052 140707991725952 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %% [markdown]
# # Review

# %% [markdown]
# failed
# - model ep1 부터 저장되지 않음.
# - ep0만 evaluate해봤지만 no sell, profit=0
#
# cuz
# - episode 1000만큼 돌릴 컴퓨터와 시간이 없어서?
